# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

spark =  SparkSession.builder.getOrCreate();
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Untitled-1.ipynb Cell 1 line 4
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=0'>1</a> from pyspark.sql import SparkSession
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=1'>2</a> from pyspark.sql import functions as F
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=3'>4</a> spark =  SparkSession.builder.getOrCreate();
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/pyspark/sql/session.py:503, in SparkSession.Builder.getOrCreate(self)
#     500     session = SparkSession(sc, options=self._options)
#     501 else:
#     502     getattr(
# --> 503         getattr(session._jvm, "SparkSession$"), "MODULE$"
# ...

# %%
DF = spark.read.parquet("HS2017_2012.parquet")
DF.show()
# Out:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/py4j/clientserver.py:503, in ClientServerConnection.send_command(self, command)
#     502 try:
# --> 503     self.socket.sendall(command.encode("utf-8"))
#     504 except Exception as e:
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# Py4JNetworkError                          Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#
# ...
